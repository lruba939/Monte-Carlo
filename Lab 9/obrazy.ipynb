# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
relaksacja = np.loadtxt("V_relaksacja.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, relaksacja)
