# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
relaksacja = np.loadtxt("V_relaksacja.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, relaksacja, cmap="hot")
plt.colorbar()
plt.title(r'V$_{\text{rel}}$')
plt.xlabel(r'i')
plt.ylabel(r'j')
# Out:
# Text(0, 0.5, 'j')

# %%
relaksacja = np.loadtxt("V_MC.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, relaksacja, cmap="hot")
plt.colorbar()
plt.title(r'V$_{\text{MC}}$')
plt.xlabel(r'i')
plt.ylabel(r'j')
# Out:
# Text(0, 0.5, 'j')

# %%
data1 = np.loadtxt("V_MC_1.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data2 = np.loadtxt("V_MC_2.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data3 = np.loadtxt("V_MC_3.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))

X = range(0, 31, 1)
Y = range(0, 31, 1)

plt.figure(figsize=(20,5), dpi=600)
########################
plt.subplot(1,3,1)
plt.pcolormesh(X, Y, data1, cmap="hot")
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 0')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,2)
plt.pcolormesh(X, Y, data2, cmap="hot")
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,3)
plt.pcolormesh(X, Y, data3, cmap="hot")
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 300, n$_{\text{length}}$ = 300, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')

plt.suptitle(r'Rozkład potencjału V obliczonego metodą Monte Carlo')
plt.subplots_adjust(top=0.8)

# %%
relaksacja = np.loadtxt("sigma_MC.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, relaksacja, cmap="hot")
plt.colorbar()
plt.title(r'$\sigma_{\text{V}}$')
plt.xlabel(r'i')
plt.ylabel(r'j')
# Out:
# Text(0, 0.5, 'j')

# %%
data1 = np.loadtxt("sigma_MC_1.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data2 = np.loadtxt("sigma_MC_2.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data3 = np.loadtxt("sigma_MC_3.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))

X = range(0, 31, 1)
Y = range(0, 31, 1)

plt.figure(figsize=(20,5), dpi=600)
########################
plt.subplot(1,3,1)
plt.pcolormesh(X, Y, data1, cmap="hot", vmin=0, vmax=0.5)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 0')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,2)
plt.pcolormesh(X, Y, data2, cmap="hot", vmin=0, vmax=0.5)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,3)
plt.pcolormesh(X, Y, data3, cmap="hot", vmin=0, vmax=0.5)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 300, n$_{\text{length}}$ = 300, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')

plt.suptitle(r'Rozkład odchylenia standardowego potencjału V obliczonego metodą Monte Carlo')
plt.subplots_adjust(top=0.8)

# %%
relaksacja = np.loadtxt("S_MC.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, relaksacja)
plt.colorbar()
plt.title(r'absorbed chains')
plt.xlabel(r'i')
plt.ylabel(r'j')
# Out:
# Text(0, 0.5, 'j')

# %%
data1 = np.loadtxt("S_MC_1.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data2 = np.loadtxt("S_MC_2.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data3 = np.loadtxt("S_MC_3.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))

X = range(0, 31, 1)
Y = range(0, 31, 1)

plt.figure(figsize=(20,5), dpi=600)
########################
plt.subplot(1,3,1)
plt.pcolormesh(X, Y, data1, vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 0')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,2)
plt.pcolormesh(X, Y, data2, vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,3)
plt.pcolormesh(X, Y, data3, vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 300, n$_{\text{length}}$ = 300, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')

plt.suptitle(r'Rozkład zaabsorbowanych łańcuchów')
plt.subplots_adjust(top=0.8)

# %%
relaksacja = np.loadtxt("V_relaksacja.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
MC = np.loadtxt("V_MC.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data = abs(relaksacja-MC)
X = range(0, 31, 1)
Y = range(0, 31, 1)
plt.pcolormesh(X, Y, data, cmap="hot")
plt.colorbar()
plt.title(r'|V$_{\text{MC}}$ - V$_{\text{rel}}$|')
plt.xlabel(r'i')
plt.ylabel(r'j')
# Out:
# Text(0, 0.5, 'j')

# %%
data1 = np.loadtxt("V_MC_1.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data2 = np.loadtxt("V_MC_2.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))
data3 = np.loadtxt("V_MC_3.dat", dtype=float, delimiter=" ", usecols=(range(0,31,1)))

data1 = np.abs(data1 - relaksacja)
data2 = np.abs(data2 - relaksacja)
data3 = np.abs(data3 - relaksacja)

X = range(0, 31, 1)
Y = range(0, 31, 1)

plt.figure(figsize=(20,5), dpi=600)
########################
plt.subplot(1,3,1)
plt.pcolormesh(X, Y, data1, cmap="hot", vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 0')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,2)
plt.pcolormesh(X, Y, data2, cmap="hot", vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 100, n$_{\text{length}}$ = 100, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')
########################
plt.subplot(1,3,3)
plt.pcolormesh(X, Y, data3, cmap="hot", vmin=0, vmax=1)
plt.colorbar()
plt.title(r'N$_{\text{chains}}$ = 300, n$_{\text{length}}$ = 300, B$_{j_0,i_0}$ = 1')
plt.xlabel(r'i')
plt.ylabel(r'j')

plt.suptitle(r'Rozkład różnicy potencjału V$_{MC}$ i V$_{rel}$')
plt.subplots_adjust(top=0.8)
