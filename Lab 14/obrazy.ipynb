# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hist = np.loadtxt("histogram.dat", dtype=float)
x = np.arange(0, 8, 8/200)
psi_100 = 2*x**2*np.exp(-x)

plt.plot(x, hist/max(hist))
plt.plot(x, psi_100/max(psi_100))

# %%
def plot_maps(data, title):
    X = range(0, len(data[1,:]), 1)
    Y = range(0, len(data[:,1]), 1)
    x = np.linspace(0.3, 1.2, num=45)
    y = np.linspace(-0.7, 0.3, num=50)
    plt.pcolormesh(x, y, data, cmap="hot")
    # plt.xticks(np.arange(0.3, 1.2, 0.02))
    # plt.yticks(np.arange(-0.7, 0.3, 0.02))
    plt.colorbar()
    plt.title(title)
    plt.xlabel(r'a')
    plt.ylabel(r'c')

# %%
energy = np.loadtxt("D:\AGH\Semestr 8\Monte-Carlo\Lab 14\map_en.dat", dtype=float)
title_en = r"Energy"
plot_maps(energy, title_en)
plt.show()

std = np.loadtxt("D:\AGH\Semestr 8\Monte-Carlo\Lab 14\map_std.dat", dtype=float)
title_std = r"$\sigma$"
plot_maps(std, title_std)
plt.show()

log_data = np.log10(std + 10**(-20))
title_log = r"log($\sigma + 10^{-20}$)"
plot_maps(log_data, title_log)
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:6: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Łukasz\AppData\Local\Temp\ipykernel_13428\2704517707.py:1: SyntaxWarning: invalid escape sequence '\A'
#   energy = np.loadtxt("D:\AGH\Semestr 8\Monte-Carlo\Lab 14\map_en.dat", dtype=float)
# C:\Users\Łukasz\AppData\Local\Temp\ipykernel_13428\2704517707.py:6: SyntaxWarning: invalid escape sequence '\A'
#   std = np.loadtxt("D:\AGH\Semestr 8\Monte-Carlo\Lab 14\map_std.dat", dtype=float)
